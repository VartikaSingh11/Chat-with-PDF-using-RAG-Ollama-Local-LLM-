# %% [markdown]
# # Install Libraries

# %%
# !pip install langchain langchain-community pypdf chromadb ollama python-dotenv
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %% [markdown]
# # Import Libraries

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import OllamaEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_community.llms import Ollama

# %% [markdown]
# # Load PDF

# %%
loader = PyPDFLoader("ml_notes.pdf")
documents = loader.load()

# %% [markdown]
# # Split Text

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

docs = text_splitter.split_documents(documents)

# %% [markdown]
# # Create Embeddings

# %%
embeddings = OllamaEmbeddings(model="nomic-embed-text")
# Out:
# C:\Users\varti\AppData\Local\Temp\ipykernel_8332\909259017.py:1: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   embeddings = OllamaEmbeddings(model="nomic-embed-text")

# %% [markdown]
# # Create Vector DB

# %% [markdown]
# db = Chroma.from_documents(docs, embeddings)

# %% [markdown]
# # Create Retriever

# %%
retriever = db.as_retriever(search_kwargs={"k": 5})

# %% [markdown]
# # Load LLM(phi3)

# %%
llm = Ollama(model="phi3")
# Out:
# C:\Users\varti\AppData\Local\Temp\ipykernel_8332\3160801430.py:1: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="phi3")

# %% [markdown]
# # Ask Question

# %%
query = "What is Machine Learning?"

docs = retriever.invoke(query)

# Debug (see what is retrieved)
for i, doc in enumerate(docs):
    print(f"\n--- Doc {i} ---\n")
    print(doc.page_content[:200])

# RAG logic
if len(docs) == 0:
    print("Not available in the document")
else:
    context = " ".join([doc.page_content for doc in docs])

    prompt = f"""
    You are a strict assistant.

    Rules:
    - Answer ONLY from the given context
    - If answer not found, say: "Not available in the document"
    - Do NOT use outside knowledge

    Context:
    {context}

    Question:
    {query}
    """

    response = llm.invoke(prompt)
    print("\nAnswer:\n", response)
# Out:
# --- Doc 0 ---
#
# significant time and resources.
#
# B. Unsupervised Algorithm
#
# Unsupervised learning is a machine learning approa ch where the algorithm
# independently identifies patterns in data without the need fo
#
# --- Doc 1 ---
#
# ARTIFICIAL INTELLIGENCE AND THEIR APPLICATIONS
# e-ISBN: 978-93-6252-717-2
# IIP Series
# INTRODUCTION AND TYPES OF MACHINE LEARNING
#
# Copyright @ 2024 Authors
#
# --- Doc 2 ---
#
# ARTIFICIAL INTELLIGENCE AND THEIR APPLICATIONS
# e-ISBN: 978-93-6252-717-2
# IIP Series
# INTRODUCTION AND TYPES OF MACHINE LEARNING
#
# Copyright @ 2024 Authors
#
# --- Doc 3 ---
#
#  Lasso Regression: It is used to not only make predictions but also to understand
# which features are most important. For example, it could analy se various factors
# affecting heart health to identif
#
# --- Doc 4 ---
#
# and the corresponding labels (desired outputs).
# b. Unlabelled Data : Used in unsuperv ised learning, this data consists of features
# ...

# %%
query = "Types of Machine Learning and explain each on of them?"

docs = retriever.invoke(query)

# Debug (see what is retrieved)
for i, doc in enumerate(docs):
    print(f"\n--- Doc {i} ---\n")
    print(doc.page_content[:200])

# RAG logic
if len(docs) == 0:
    print("Not available in the document")
else:
    context = " ".join([doc.page_content for doc in docs])

    prompt = f"""
    You are a strict assistant.

    Rules:
    - Answer ONLY from the given context
    - If answer not found, say: "Not available in the document"
    - Do NOT use outside knowledge

    Context:
    {context}

    Question:
    {query}
    """

    response = llm.invoke(prompt)
    print("\nAnswer:\n", response)
# Out:
# --- Doc 0 ---
#
# Advantages and Disadvantages of Unsupervised Learning Algorithm
#
# Here are some advantages and disadvantages of Unsupervised Learning Algorithm:
#
# Advantages of Unsupervised Learning
#
#  Complex Ta
#
# --- Doc 1 ---
#
#  Lasso Regression: It is used to not only make predictions but also to understand
# which features are most important. For example, it could analy se various factors
# affecting heart health to identif
#
# --- Doc 2 ---
#
# significant time and resources.
#
# B. Unsupervised Algorithm
#
# Unsupervised learning is a machine learning approa ch where the algorithm
# independently identifies patterns in data without the need fo
#
# --- Doc 3 ---
#
# ARTIFICIAL INTELLIGENCE AND THEIR APPLICATIONS
# e-ISBN: 978-93-6252-717-2
# IIP Series
# INTRODUCTION AND TYPES OF MACHINE LEARNING
#
# Copyright @ 2024 Authors
#
# --- Doc 4 ---
#
# recommend things to customers by learning what they like.
#
# III. TYPES OF MACHINE LEARNING
#
# ...

# %%
query = "What is Food?"

docs = retriever.invoke(query)

# Debug (see what is retrieved)
for i, doc in enumerate(docs):
    print(f"\n--- Doc {i} ---\n")
    print(doc.page_content[:200])

# RAG logic
if len(docs) == 0:
    print("Not available in the document")
else:
    context = " ".join([doc.page_content for doc in docs])

    prompt = f"""
    You are a strict assistant.

    Rules:
    - Answer ONLY from the given context
    - If answer not found, say: "Not available in the document"
    - Do NOT use outside knowledge

    Context:
    {context}

    Question:
    {query}
    """

    response = llm.invoke(prompt)
    print("\nAnswer:\n", response)
# Out:
# --- Doc 0 ---
#
# significant time and resources.
#
# B. Unsupervised Algorithm
#
# Unsupervised learning is a machine learning approa ch where the algorithm
# independently identifies patterns in data without the need fo
#
# --- Doc 1 ---
#
# ARTIFICIAL INTELLIGENCE AND THEIR APPLICATIONS
# e-ISBN: 978-93-6252-717-2
# IIP Series
# INTRODUCTION AND TYPES OF MACHINE LEARNING
#
# Copyright @ 2024 Authors
#
# --- Doc 2 ---
#
# ARTIFICIAL INTELLIGENCE AND THEIR APPLICATIONS
# e-ISBN: 978-93-6252-717-2
# IIP Series
# INTRODUCTION AND TYPES OF MACHINE LEARNING
#
# Copyright @ 2024 Authors
#
# --- Doc 3 ---
#
#  Lasso Regression: It is used to not only make predictions but also to understand
# which features are most important. For example, it could analy se various factors
# affecting heart health to identif
#
# --- Doc 4 ---
#
# Advantages and Disadvantages of Unsupervised Learning Algorithm
#
# Here are some advantages and disadvantages of Unsupervised Learning Algorithm:
#
# ...
